# %%
a = 1011
A = 'eusei'
print(A)
# Out:
# eusei

# %%
a = 10
b = 20

# %%
print("print(a+b)", a+b)
print("print(a-b)", a-b)
print("print(a*b)", a*b)
print("print(a/b)", a/b)
print("print(a//b)", a//b)
print("print(a%b)", a%b)
print("print(a**b)", b**a)
print("print(a==b)", a==b)
print("print(a!=b)", a!=b)
print("print(a<b)", a<b)
print("print(a<=b)", a<=b)  
print("print(a>b)", a>b)
print("print(a>=b)", a>=b)
print("print(a and b)", a and b)
